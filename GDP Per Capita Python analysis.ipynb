# %% [markdown]
# # Pandas, Matplotlib and Seaborn

# %%
import pandas as pd

# %% [markdown]
# [Dataset Soruce](https://www.kaggle.com/datasets/rajkumarpandey02/gdp-in-usd-per-capita-income-by-country)

# %% [markdown]
# CONTENT
# <p>The figures presented here do not take into account differences in the cost of living in different countries, and the results vary greatly from one year to another based on fluctuations in the exchange rates of the country's currency. Such fluctuations change a country's ranking from one year to the next, even though they often make little or no difference to the standard of living of its population.
#
# GDP per capita is often considered an indicator of a country's standard of living; however, this is inaccurate because GDP per capita is not a measure of personal income.
#
# Comparisons of national income are also frequently made on the basis of purchasing power parity (PPP), to adjust for differences in the cost of living in different countries. (See List of countries by GDP (PPP) per capita.) PPP largely removes the exchange rate problem but not others; it does not reflect the value of economic output in international trade, and it also requires more estimation than GDP per capita. On the whole, PPP per capita figures are more narrowly spread than nominal GDP per capita figures.</p>

# %%
df = pd.read_csv("GDP (nominal) per Capita.csv",encoding= 'unicode_escape', index_col=0)

# %% [markdown]
# # EDA (Exploratory Data Analysis)

# %%
df
# Out:
#     Country/Territory UN_Region  IMF_Estimate  IMF_Year  WorldBank_Estimate  \
# 1              Monaco    Europe             0         0              234316
# 2       Liechtenstein    Europe             0         0              157755
# 3          Luxembourg    Europe        132372      2023              133590
# 4             Ireland    Europe        114581      2023              100172
# 5             Bermuda  Americas             0         0              114090
# ..                ...       ...           ...       ...                 ...
# 219            Malawi    Africa           496      2023                 635
# 220       South Sudan    Africa           467      2023                1072
# 221      Sierra Leone    Africa           415      2023                 480
# 222       Afghanistan      Asia           611      2020                 369
# 223           Burundi    Africa           249      2023                 222
#
#      WorldBank_Year  UN_Estimate UN_Year
# 1              2021       234317    2021
# 2              2020       169260    2021
# 3              2021       133745    2021
# 4              2021       101109    2021
# 5              2021       112653    2021
# ..              ...          ...     ...
# 219            2021          613    2021
# 220            2015          400    2021
# 221            2021          505    2021
# 222            2021          373    2021
# 223            2021          311    2021
#
# [223 rows x 8 columns]

# %%
df[["Country/Territory","IMF_Year"]].tail()
# Out:
#     Country/Territory  IMF_Year
# 219            Malawi      2023
# 220       South Sudan      2023
# 221      Sierra Leone      2023
# 222       Afghanistan      2020
# 223           Burundi      2023

# %%
df[["UN_Region","WorldBank_Estimate"]].head(10)
# Out:
#    UN_Region  WorldBank_Estimate
# 1     Europe              234316
# 2     Europe              157755
# 3     Europe              133590
# 4     Europe              100172
# 5   Americas              114090
# 6     Europe               89154
# 7     Europe               91992
# 8       Asia               72794
# 9     Europe               87158
# 10  Americas               86569

# %%
avg_imf_estimate = df['IMF_Estimate'].mean()
below_imf_estimate = df[(df['IMF_Estimate'] < avg_imf_estimate) & (df["IMF_Estimate"] != 0)]
print(avg_imf_estimate)
# Out:
# 15351.632286995517

# %%
# Display the result
print("below_imf_estimate")
below_imf_estimate
# Out:
# below_imf_estimate
#     Country/Territory UN_Region  IMF_Estimate  IMF_Year  WorldBank_Estimate  \
# 87           Bulgaria    Europe         14893      2023               12222
# 88              Palau   Oceania         14804      2023               12084
# 89         Costa Rica  Americas         14733      2023               12472
# 90             Russia    Europe         14403      2023               12195
# 91              China      Asia         13721      2023               12556
# ..                ...       ...           ...       ...                 ...
# 219            Malawi    Africa           496      2023                 635
# 220       South Sudan    Africa           467      2023                1072
# 221      Sierra Leone    Africa           415      2023                 480
# 222       Afghanistan      Asia           611      2020                 369
# 223           Burundi    Africa           249      2023                 222
#
#      WorldBank_Year  UN_Estimate UN_Year
# 87             2021        12207    2021
# 88             2021        12084    2021
# 89             2021        12472    2021
# 90             2021        12259    2021
# 91             2021        12437    2021
# ..              ...          ...     ...
# 219            2021          613    2021
# 220            2015          400    2021
# 221            2021          505    2021
# 222            2021          373    2021
# 223            2021          311    2021
#
# [133 rows x 8 columns]

# %%
df[["Country/Territory","UN_Estimate"]][0:10]
# Out:
#    Country/Territory  UN_Estimate
# 1             Monaco       234317
# 2      Liechtenstein       169260
# 3         Luxembourg       133745
# 4            Ireland       101109
# 5            Bermuda       112653
# 6             Norway        89242
# 7        Switzerland        93525
# 8          Singapore        66822
# 9        Isle of Man            0
# 10    Cayman Islands        85250

# %%
df.sample(10)
# Out:
#             Country/Territory UN_Region  IMF_Estimate  IMF_Year  \
# 59                   Portugal    Europe         26012      2023
# 103                Montenegro    Europe         11289      2023
# 175                   Nigeria    Africa          2280      2023
# 61   Northern Mariana Islands   Oceania             0         0
# 180                  Cambodia      Asia          1896      2023
# 140                    Jordan      Asia          5048      2023
# 57                  Lithuania    Europe         28094      2023
# 41                      Italy    Europe         36812      2023
# 207                    Gambia    Africa           861      2023
# 4                     Ireland    Europe        114581      2023
#
#      WorldBank_Estimate  WorldBank_Year  UN_Estimate UN_Year
# 59                24568            2021        24651    2021
# 103                9466            2021         9252    2021
# 175                2066            2021         2019    2021
# 61                23707            2019            0       0
# 180                1625            2021         1608    2021
# 140                4103            2021         4058    2021
# 57                23723            2021        23844    2021
# 41                35658            2021        35579    2021
# 207                 772            2021          772    2021
# 4                100172            2021       101109    2021

# %%
IMF_average = 15351.632287
below_threshold_rows = df[df['IMF_Estimate'] < IMF_average]

# %%
below_threshold_rows
# Out:
#     Country/Territory UN_Region  IMF_Estimate  IMF_Year  WorldBank_Estimate  \
# 1              Monaco    Europe             0         0              234316
# 2       Liechtenstein    Europe             0         0              157755
# 5             Bermuda  Americas             0         0              114090
# 9         Isle of Man    Europe             0         0               87158
# 10     Cayman Islands  Americas             0         0               86569
# ..                ...       ...           ...       ...                 ...
# 219            Malawi    Africa           496      2023                 635
# 220       South Sudan    Africa           467      2023                1072
# 221      Sierra Leone    Africa           415      2023                 480
# 222       Afghanistan      Asia           611      2020                 369
# 223           Burundi    Africa           249      2023                 222
#
#      WorldBank_Year  UN_Estimate UN_Year
# 1              2021       234317    2021
# 2              2020       169260    2021
# 5              2021       112653    2021
# 9              2019            0       0
# 10             2021        85250    2021
# ..              ...          ...     ...
# 219            2021          613    2021
# 220            2015          400    2021
# 221            2021          505    2021
# 222            2021          373    2021
# 223            2021          311    2021
#
# [159 rows x 8 columns]

# %%
df.loc[df["WorldBank_Estimate"]>=50000]
# Out:
#    Country/Territory UN_Region  IMF_Estimate  IMF_Year  WorldBank_Estimate  \
# 1             Monaco    Europe             0         0              234316
# 2      Liechtenstein    Europe             0         0              157755
# 3         Luxembourg    Europe        132372      2023              133590
# 4            Ireland    Europe        114581      2023              100172
# 5            Bermuda  Americas             0         0              114090
# 6             Norway    Europe        101103      2023               89154
# 7        Switzerland    Europe         98767      2023               91992
# 8          Singapore      Asia         91100      2023               72794
# 9        Isle of Man    Europe             0         0               87158
# 10    Cayman Islands  Americas             0         0               86569
# 11             Qatar      Asia         83891      2023               66838
# 12     United States  Americas         80034      2023               70249
# 13           Iceland    Europe         75180      2023               68728
# 14   Channel Islands    Europe             0         0               75153
# 15     Faroe Islands    Europe             0         0               69010
# 16           Denmark    Europe         68827      2023               68008
# 17         Australia   Oceania         64964      2023               60443
# 18       Netherlands    Europe         61098      2023               57768
# 19         Greenland  Americas             0         0               54571
# 20           Austria    Europe         56802      2023               53638
# 21            Israel      Asia         55535      2023               52171
# 22            Sweden    Europe         55395      2023               61029
# 23           Finland    Europe         54351      2023               53655
# 24           Belgium    Europe         53377      2023               51247
# 26            Canada  Americas         52722      2023               51988
# 28           Germany    Europe         51383      2023               51204
#
#     WorldBank_Year  UN_Estimate UN_Year
# 1             2021       234317    2021
# 2             2020       169260    2021
# 3             2021       133745    2021
# 4             2021       101109    2021
# 5             2021       112653    2021
# 6             2021        89242    2021
# 7             2021        93525    2021
# 8             2021        66822    2021
# 9             2019            0       0
# 10            2021        85250    2021
# 11            2021        66799    2021
# 12            2021        69185    2021
# 13            2021        69133    2021
# 14            2007            0       0
# 15            2021            0       0
# 16            2021        68037    2021
# 17            2021        66916    2021
# 18            2021        57871    2021
# 19            2020        58185    2021
# 20            2021        53840    2021
# 21            2021        54111    2021
# 22            2021        60730    2021
# 23            2021        53703    2021
# 24            2021        51166    2021
# 26            2021        52112    2021
# 28            2021        51073    2021

# %% [markdown]
# #### What is Worldbank Estimate for the UK?

# %%
findUK = df[df['Country/Territory'] == "United Kingdom"]
findUK
# Out:
#    Country/Territory UN_Region  IMF_Estimate  IMF_Year  WorldBank_Estimate  \
# 33    United Kingdom    Europe         46371      2023               46510
#
#     WorldBank_Year  UN_Estimate UN_Year
# 33            2021        46542    2021

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 223 entries, 1 to 223
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Country/Territory   223 non-null    object
#  1   UN_Region           223 non-null    object
#  2   IMF_Estimate        223 non-null    int64
#  3   IMF_Year            223 non-null    int64
#  4   WorldBank_Estimate  223 non-null    int64
#  5   WorldBank_Year      223 non-null    int64
#  6   UN_Estimate         223 non-null    int64
#  7   UN_Year             223 non-null    object
# dtypes: int64(5), object(3)
# memory usage: 15.7+ KB

# %%
df.describe()
# Out:
#         IMF_Estimate     IMF_Year  WorldBank_Estimate  WorldBank_Year  \
# count     223.000000   223.000000          223.000000      223.000000
# mean    15351.632287  1787.098655        18927.417040     1957.278027
# std     22550.899445   650.695912        29103.564915      353.145867
# min         0.000000     0.000000            0.000000        0.000000
# 25%      1406.500000  2023.000000         2273.500000     2021.000000
# 50%      5421.000000  2023.000000         6805.000000     2021.000000
# 75%     19697.000000  2023.000000        23715.000000     2021.000000
# max    132372.000000  2023.000000       234316.000000     2021.000000
#
#          UN_Estimate
# count     223.000000
# mean    17767.304933
# std     28698.104167
# min         0.000000
# 25%      2039.000000
# 50%      6396.000000
# 75%     20740.000000
# max    234317.000000

# %% [markdown]
# ### Number of countries per region

# %%
df.UN_Region.value_counts()
# Out:
# UN_Region
# Africa      55
# Asia        51
# Europe      48
# Americas    48
# Oceania     20
# World        1
# Name: count, dtype: int64

# %%
df[df["UN_Region"]=="World"]
# Out:
#    Country/Territory UN_Region  IMF_Estimate  IMF_Year  WorldBank_Estimate  \
# 93             World     World         13440      2023               12235
#
#     WorldBank_Year  UN_Estimate UN_Year
# 93            2021        12230    2021

# %%
df[df["IMF_Estimate"]>= 13440]
# Out:
#    Country/Territory UN_Region  IMF_Estimate  IMF_Year  WorldBank_Estimate  \
# 3         Luxembourg    Europe        132372      2023              133590
# 4            Ireland    Europe        114581      2023              100172
# 6             Norway    Europe        101103      2023               89154
# 7        Switzerland    Europe         98767      2023               91992
# 8          Singapore      Asia         91100      2023               72794
# ..               ...       ...           ...       ...                 ...
# 89        Costa Rica  Americas         14733      2023               12472
# 90            Russia    Europe         14403      2023               12195
# 91             China      Asia         13721      2023               12556
# 92         Argentina  Americas         13709      2023               10636
# 93             World     World         13440      2023               12235
#
#     WorldBank_Year  UN_Estimate UN_Year
# 3             2021       133745    2021
# 4             2021       101109    2021
# 6             2021        89242    2021
# 7             2021        93525    2021
# 8             2021        66822    2021
# ..             ...          ...     ...
# 89            2021        12472    2021
# 90            2021        12259    2021
# 91            2021        12437    2021
# 92            2021        10761    2021
# 93            2021        12230    2021
#
# [71 rows x 8 columns]

# %%
df[df["UN_Region"]=="Europe"]
# Out:
#           Country/Territory UN_Region  IMF_Estimate  IMF_Year  \
# 1                    Monaco    Europe             0         0
# 2             Liechtenstein    Europe             0         0
# 3                Luxembourg    Europe        132372      2023
# 4                   Ireland    Europe        114581      2023
# 6                    Norway    Europe        101103      2023
# 7               Switzerland    Europe         98767      2023
# 9               Isle of Man    Europe             0         0
# 13                  Iceland    Europe         75180      2023
# 14          Channel Islands    Europe             0         0
# 15            Faroe Islands    Europe             0         0
# 16                  Denmark    Europe         68827      2023
# 18              Netherlands    Europe         61098      2023
# 20                  Austria    Europe         56802      2023
# 22                   Sweden    Europe         55395      2023
# 23                  Finland    Europe         54351      2023
# 24                  Belgium    Europe         53377      2023
# 25               San Marino    Europe         52949      2023
# 28                  Germany    Europe         51383      2023
# 33           United Kingdom    Europe         46371      2023
# 34                   France    Europe         44408      2023
# 35                  Andorra    Europe         44387      2023
# 36      European Union[n 1]    Europe         39940      2023
# 40                    Malta    Europe         36989      2023
# 41                    Italy    Europe         36812      2023
# 51                 Slovenia    Europe         32214      2023
# 52           Czech Republic    Europe         31368      2023
# 53                    Spain    Europe         31223      2023
# 54                  Estonia    Europe         31209      2023
# 57                Lithuania    Europe         28094      2023
# 59                 Portugal    Europe         26012      2023
# 60                   Latvia    Europe         25136      2023
# 62                 Slovakia    Europe         23457      2023
# 63                   Greece    Europe         22595      2023
# 70                  Croatia    Europe         20537      2023
# 72                   Poland    Europe         19912      2023
# 75                  Hungary    Europe         19385      2023
# 78                  Romania    Europe         18530      2023
# 87                 Bulgaria    Europe         14893      2023
# 90                   Russia    Europe         14403      2023
# 103              Montenegro    Europe         11289      2023
# 106                  Serbia    Europe         10849      2023
# 112  Bosnia and Herzegovina    Europe          8223      2023
# 115                 Belarus    Europe          7944      2023
# 118         North Macedonia    Europe          7384      2023
# 120                 Albania    Europe          7058      2023
# 127                 Moldova    Europe          6342      2023
# 133                  Kosovo    Europe          5641      2023
# 143                 Ukraine    Europe          4654      2023
#
#      WorldBank_Estimate  WorldBank_Year  UN_Estimate UN_Year
# 1                234316            2021       234317    2021
# 2                157755            2020       169260    2021
# 3                133590            2021       133745    2021
# 4                100172            2021       101109    2021
# 6                 89154            2021        89242    2021
# 7                 91992            2021        93525    2021
# 9                 87158            2019            0       0
# 13                68728            2021        69133    2021
# 14                75153            2007            0       0
# 15                69010            2021            0       0
# 16                68008            2021        68037    2021
# 18                57768            2021        57871    2021
# 20                53638            2021        53840    2021
# 22                61029            2021        60730    2021
# 23                53655            2021        53703    2021
# 24                51247            2021        51166    2021
# 25                45320            2020        50425    2021
# 28                51204            2021        51073    2021
# 33                46510            2021        46542    2021
# 34                43659            2021        44229    2021
# 35                42137            2021        42066    2021
# 36                38411            2021        31875    2021
# 40                33487            2021        33642    2021
# 41                35658            2021        35579    2021
# 51                29291            2021        29135    2021
# 52                26821            2021        26809    2021
# 53                30104            2021        30058    2021
# 54                27944            2021        27991    2021
# 57                23723            2021        23844    2021
# 59                24568            2021        24651    2021
# 60                21148            2021        21267    2021
# 62                21392            2021        21390    2021
# 63                20193            2021        20571    2021
# 70                17685            2021        16983    2021
# 72                18000            2021        17736    2021
# 75                18728            2021        18728    2021
# 78                14858            2021        14698    2021
# 87                12222            2021        12207    2021
# 90                12195            2021        12259    2021
# 103                9466            2021         9252    2021
# 106                9230            2021         8643    2021
# 112                7143            2021         7143    2021
# 115                7302            2021         7121    2021
# 118                6695            2021         6600    2021
# 120                6493            2021         6396    2021
# 127                5231            2021         4468    2021
# 133                5270            2021         5663    2021
# 143                4836            2021         4596    2021

# %%
df.iloc[35]
# Out:
# Country/Territory     European Union[n 1]
# UN_Region                          Europe
# IMF_Estimate                        39940
# IMF_Year                             2023
# WorldBank_Estimate                  38411
# WorldBank_Year                       2021
# UN_Estimate                         31875
# UN_Year                              2021
# Name: 36, dtype: object

# %%
df.loc[36]
# Out:
# Country/Territory     European Union[n 1]
# UN_Region                          Europe
# IMF_Estimate                        39940
# IMF_Year                             2023
# WorldBank_Estimate                  38411
# WorldBank_Year                       2021
# UN_Estimate                         31875
# UN_Year                              2021
# Name: 36, dtype: object

# %% [markdown]
# #### highest gdp per capita for each region by UN Estimate?

# %%
df.UN_Region.unique()
# Out:
# array(['Europe', 'Americas', 'Asia', 'Oceania', 'Africa', 'World'],
#       dtype=object)

# %%
df[df["UN_Region"]=="Asia"].head(1)
# Out:
#   Country/Territory UN_Region  IMF_Estimate  IMF_Year  WorldBank_Estimate  \
# 8         Singapore      Asia         91100      2023               72794
#
#    WorldBank_Year  UN_Estimate UN_Year
# 8            2021        66822    2021

# %%
df[df["UN_Region"]=="Asia"].nlargest(1, columns="UN_Estimate")
# Out:
#   Country/Territory UN_Region  IMF_Estimate  IMF_Year  WorldBank_Estimate  \
# 8         Singapore      Asia         91100      2023               72794
#
#    WorldBank_Year  UN_Estimate UN_Year
# 8            2021        66822    2021

# %%
df[df["UN_Region"]=="Asia"].nsmallest(1, columns="UN_Estimate")
# Out:
#    Country/Territory UN_Region  IMF_Estimate  IMF_Year  WorldBank_Estimate  \
# 46            Taiwan      Asia         33907      2023                   0
#
#     WorldBank_Year  UN_Estimate UN_Year
# 46               0            0       0

# %% [markdown]
# ## Which countries below average by IMF world estimate?

# %%
IMF_average = 15351.632287
below_threshold_rows = df[(df['IMF_Estimate'] < IMF_average) & (df['IMF_Estimate'] != 0 )]

# %%
below_threshold_rows
# Out:
#     Country/Territory UN_Region  IMF_Estimate  IMF_Year  WorldBank_Estimate  \
# 87           Bulgaria    Europe         14893      2023               12222
# 88              Palau   Oceania         14804      2023               12084
# 89         Costa Rica  Americas         14733      2023               12472
# 90             Russia    Europe         14403      2023               12195
# 91              China      Asia         13721      2023               12556
# ..                ...       ...           ...       ...                 ...
# 219            Malawi    Africa           496      2023                 635
# 220       South Sudan    Africa           467      2023                1072
# 221      Sierra Leone    Africa           415      2023                 480
# 222       Afghanistan      Asia           611      2020                 369
# 223           Burundi    Africa           249      2023                 222
#
#      WorldBank_Year  UN_Estimate UN_Year
# 87             2021        12207    2021
# 88             2021        12084    2021
# 89             2021        12472    2021
# 90             2021        12259    2021
# 91             2021        12437    2021
# ..              ...          ...     ...
# 219            2021          613    2021
# 220            2015          400    2021
# 221            2021          505    2021
# 222            2021          373    2021
# 223            2021          311    2021
#
# [133 rows x 8 columns]

# %% [markdown]
# ### IMF estimate 0 values

# %%
df[df['IMF_Estimate'] == 0]
# Out:
#               Country/Territory UN_Region  IMF_Estimate  IMF_Year  \
# 1                        Monaco    Europe             0         0
# 2                 Liechtenstein    Europe             0         0
# 5                       Bermuda  Americas             0         0
# 9                   Isle of Man    Europe             0         0
# 10               Cayman Islands  Americas             0         0
# 14              Channel Islands    Europe             0         0
# 15                Faroe Islands    Europe             0         0
# 19                    Greenland  Americas             0         0
# 31       British Virgin Islands  Americas             0         0
# 37            US Virgin Islands  Americas             0         0
# 39                New Caledonia   Oceania             0         0
# 42                         Guam   Oceania             0         0
# 58    Sint Maarten (Dutch part)  Americas             0         0
# 61     Northern Mariana Islands   Oceania             0         0
# 65   Saint Martin (French part)  Americas             0         0
# 68     Turks and Caicos Islands  Americas             0         0
# 71             French Polynesia   Oceania             0         0
# 76                 Cook Islands   Oceania             0         0
# 77                     Anguilla  Americas             0         0
# 82                     Cura̤ao  Americas             0         0
# 85                   Montserrat  Americas             0         0
# 86               American Samoa   Oceania             0         0
# 104                        Cuba  Americas             0         0
# 196                    Zanzibar    Africa             0         0
# 204                       Syria      Asia             0         0
# 212                 North Korea      Asia             0         0
#
#      WorldBank_Estimate  WorldBank_Year  UN_Estimate UN_Year
# 1                234316            2021       234317    2021
# 2                157755            2020       169260    2021
# 5                114090            2021       112653    2021
# 9                 87158            2019            0       0
# 10                86569            2021        85250    2021
# 14                75153            2007            0       0
# 15                69010            2021            0       0
# 19                54571            2020        58185    2021
# 31                    0               0        49444    2021
# 37                39552            2020            0       0
# 39                37160            2021        34994    2021
# 42                35905            2021            0       0
# 58                28988            2018        26199    2021
# 61                23707            2019            0       0
# 65                21921            2014            0       0
# 68                20909            2021        20909    2021
# 71                19915            2021        19915    2021
# 76                    0               0        19264    2021
# 77                    0               0        19216    2021
# 82                17718            2021        14183    2021
# 85                    0               0        16199    2021
# 86                15743            2021            0       0
# 104                9500            2020        11255    2021
# 196                   0               0         1211    2021
# 204                 533            2020          925    2021
# 212                   0               0          654    2021

# %% [markdown]
# ## Which country has highest UN Estimate?

# %%
df[df['UN_Estimate']==df['UN_Estimate'].max()]
# Out:
#   Country/Territory UN_Region  IMF_Estimate  IMF_Year  WorldBank_Estimate  \
# 1            Monaco    Europe             0         0              234316
#
#    WorldBank_Year  UN_Estimate UN_Year
# 1            2021       234317    2021

# %% [markdown]
# ## Which country has highest Worlbank Estimate?

# %%
df[df['WorldBank_Estimate']==df['WorldBank_Estimate'].max()]
# Out:
#   Country/Territory UN_Region  IMF_Estimate  IMF_Year  WorldBank_Estimate  \
# 1            Monaco    Europe             0         0              234316
#
#    WorldBank_Year  UN_Estimate UN_Year
# 1            2021       234317    2021

# %% [markdown]
# ## Which country has highest IMF Estimate?

# %%
df[df['IMF_Estimate']==df['IMF_Estimate'].max()]
# Out:
#   Country/Territory UN_Region  IMF_Estimate  IMF_Year  WorldBank_Estimate  \
# 3        Luxembourg    Europe        132372      2023              133590
#
#    WorldBank_Year  UN_Estimate UN_Year
# 3            2021       133745    2021

# %% [markdown]
# ## Checking Missing Values

# %%
df.isnull()
# Out:
#      Country/Territory  UN_Region  IMF_Estimate  IMF_Year  WorldBank_Estimate  \
# 1                False      False         False     False               False
# 2                False      False         False     False               False
# 3                False      False         False     False               False
# 4                False      False         False     False               False
# 5                False      False         False     False               False
# ..                 ...        ...           ...       ...                 ...
# 219              False      False         False     False               False
# 220              False      False         False     False               False
# 221              False      False         False     False               False
# 222              False      False         False     False               False
# 223              False      False         False     False               False
#
#      WorldBank_Year  UN_Estimate  UN_Year
# 1             False        False    False
# 2             False        False    False
# 3             False        False    False
# 4             False        False    False
# 5             False        False    False
# ..              ...          ...      ...
# 219           False        False    False
# 220           False        False    False
# 221           False        False    False
# 222           False        False    False
# 223           False        False    False
#
# [223 rows x 8 columns]

# %%
df.isnull().sum()
# Out:
# Country/Territory     0
# UN_Region             0
# IMF_Estimate          0
# IMF_Year              0
# WorldBank_Estimate    0
# WorldBank_Year        0
# UN_Estimate           0
# UN_Year               0
# dtype: int64

# %% [markdown]
# ### How to replace 0 values by using average?

# %%
df.loc[df['IMF_Estimate'] == 0, 'IMF_Estimate'] = (df['WorldBank_Estimate'] + df['UN_Estimate'])/2
# Out:
# C:\Users\yusufs\AppData\Local\Temp\ipykernel_6516\1177441962.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[234316.5 163507.5 113371.5  43579.   85909.5  37576.5  34505.   56378.
#   24722.   19776.   36077.   17952.5  27593.5  11853.5  10960.5  20909.
#   19915.    9632.    9608.   15950.5   8099.5   7871.5  10377.5    605.5
#     729.     327. ]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[df['IMF_Estimate'] == 0, 'IMF_Estimate'] = (df['WorldBank_Estimate'] + df['UN_Estimate'])/2

# %%
df
# Out:
#     Country/Territory UN_Region  IMF_Estimate  IMF_Year  WorldBank_Estimate  \
# 1              Monaco    Europe      234316.5         0              234316
# 2       Liechtenstein    Europe      163507.5         0              157755
# 3          Luxembourg    Europe      132372.0      2023              133590
# 4             Ireland    Europe      114581.0      2023              100172
# 5             Bermuda  Americas      113371.5         0              114090
# ..                ...       ...           ...       ...                 ...
# 219            Malawi    Africa         496.0      2023                 635
# 220       South Sudan    Africa         467.0      2023                1072
# 221      Sierra Leone    Africa         415.0      2023                 480
# 222       Afghanistan      Asia         611.0      2020                 369
# 223           Burundi    Africa         249.0      2023                 222
#
#      WorldBank_Year  UN_Estimate UN_Year
# 1              2021       234317    2021
# 2              2020       169260    2021
# 3              2021       133745    2021
# 4              2021       101109    2021
# 5              2021       112653    2021
# ..              ...          ...     ...
# 219            2021          613    2021
# 220            2015          400    2021
# 221            2021          505    2021
# 222            2021          373    2021
# 223            2021          311    2021
#
# [223 rows x 8 columns]

# %%
(df['WorldBank_Estimate'] + df['UN_Estimate'])/2
# Out:
# 1      234316.5
# 2      163507.5
# 3      133667.5
# 4      100640.5
# 5      113371.5
#          ...
# 219       624.0
# 220       736.0
# 221       492.5
# 222       371.0
# 223       266.5
# Length: 223, dtype: float64

# %%
df.loc[df['WorldBank_Estimate'] == 0, 'WorldBank_Estimate'] = (df['IMF_Estimate'] + df['UN_Estimate'])/2
# Out:
# C:\Users\yusufs\AppData\Local\Temp\ipykernel_6516\1293667684.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[37083.   16953.5  14448.   14412.   12149.25   908.25   490.5 ]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[df['WorldBank_Estimate'] == 0, 'WorldBank_Estimate'] = (df['IMF_Estimate'] + df['UN_Estimate'])/2

# %%
df[df["WorldBank_Estimate"]==0]
# Out:
# Empty DataFrame
# Columns: [Country/Territory, UN_Region, IMF_Estimate, IMF_Year, WorldBank_Estimate, WorldBank_Year, UN_Estimate, UN_Year]
# Index: []

# %% [markdown]
# ## group by function

# %% [markdown]
# [group by learn](https://www.geeksforgeeks.org/pandas-groupby/)

# %% [markdown]
# [group by learn](https://www.w3schools.com/mysql/mysql_groupby.asp)

# %%
df.head()
# Out:
#   Country/Territory UN_Region  IMF_Estimate  IMF_Year  WorldBank_Estimate  \
# 1            Monaco    Europe      234316.5         0            234316.0
# 2     Liechtenstein    Europe      163507.5         0            157755.0
# 3        Luxembourg    Europe      132372.0      2023            133590.0
# 4           Ireland    Europe      114581.0      2023            100172.0
# 5           Bermuda  Americas      113371.5         0            114090.0
#
#    WorldBank_Year  UN_Estimate UN_Year
# 1            2021       234317    2021
# 2            2020       169260    2021
# 3            2021       133745    2021
# 4            2021       101109    2021
# 5            2021       112653    2021

# %%
df.groupby("UN_Region").mean(numeric_only=True)
# Out:
#            IMF_Estimate     IMF_Year  WorldBank_Estimate  WorldBank_Year  \
# UN_Region
# Africa      2813.354545  1986.218182         2487.350000     1983.963636
# Americas   20280.531250  1517.250000        19891.046875     1894.270833
# Asia       16685.960784  1943.509804        14263.352941     1941.607843
# Europe     45144.343750  1812.270833        45193.687500     2020.625000
# Oceania    14298.225000  1416.100000        15836.050000     1919.850000
# World      13440.000000  2023.000000        12235.000000     2021.000000
#
#             UN_Estimate
# UN_Region
# Africa      2417.927273
# Americas   18703.750000
# Asia       14069.019608
# Europe     40610.791667
# Oceania    12613.750000
# World      12230.000000

# %%
df.groupby("UN_Region").sum(numeric_only=True)
# Out:
#            IMF_Estimate  IMF_Year  WorldBank_Estimate  WorldBank_Year  \
# UN_Region
# Africa         154734.5    109242           136804.25          109118
# Americas       973465.5     72828           954770.25           90925
# Asia           850984.0     99119           727431.00           99022
# Europe        2166928.5     86989          2169297.00           96990
# Oceania        285964.5     28322           316721.00           38397
# World           13440.0      2023            12235.00            2021
#
#            UN_Estimate
# UN_Region
# Africa          132986
# Americas        897780
# Asia            717520
# Europe         1949318
# Oceania         252275
# World            12230

# %%
df.groupby("WorldBank_Year").mean(numeric_only=True)
# Out:
#                 IMF_Estimate     IMF_Year  WorldBank_Estimate   UN_Estimate
# WorldBank_Year
# 0               12414.428571   289.000000        13777.785714  15141.142857
# 2007            37576.500000     0.000000        75153.000000      0.000000
# 2011              715.000000  2023.000000          644.000000    623.000000
# 2014             7300.250000  1011.500000        18948.500000   1982.500000
# 2015              467.000000  2023.000000         1072.000000    400.000000
# 2018            14083.250000  1011.500000        14845.000000  13250.500000
# 2019            22832.500000   674.333333        39403.333333   2836.000000
# 2020            48194.714286   578.000000        47361.571429  46028.571429
# 2021            19453.417085  1921.301508        18224.206030  17557.407035

# %%
df.groupby("UN_Region")

# %% [markdown]
# ## Visualization

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Histogram

# %%
df.hist(figsize=(12,9))
plt.show()

# %%
df[["IMF_Estimate", "UN_Estimate", "WorldBank_Estimate"]].hist(figsize=(12,9))

plt.show()

# %%
df[["IMF_Estimate", "UN_Estimate", "WorldBank_Estimate"]].hist(bins=5, figsize=(12,9))

plt.show()

# %%
df["WorldBank_Estimate"].agg(["min","max"])
# Out:
# min       222.0
# max    234316.0
# Name: WorldBank_Estimate, dtype: float64

# %%
234316/5
#1 bin size if bins=5
# Out:
# 46863.2

# %%
234316/10
#1 bin size if bins not given any number
# Out:
# 23431.6

# %%
df[["IMF_Estimate", "UN_Estimate", "WorldBank_Estimate"]].hist(bins=3, figsize=(12,9))

plt.show()

# %%
df[["IMF_Estimate", "UN_Estimate", "WorldBank_Estimate"]].hist(bins=15, figsize=(15,12))


plt.show()

# %% [markdown]
# ### Correlation Heatmap

# %%
df.corr(numeric_only=True)
# Out:
#                     IMF_Estimate  IMF_Year  WorldBank_Estimate  \
# IMF_Estimate            1.000000 -0.240161            0.977825
# IMF_Year               -0.240161  1.000000           -0.350830
# WorldBank_Estimate      0.977825 -0.350830            1.000000
# WorldBank_Year          0.046227  0.416468            0.034409
# UN_Estimate             0.976263 -0.210825            0.938705
#
#                     WorldBank_Year  UN_Estimate
# IMF_Estimate              0.046227     0.976263
# IMF_Year                  0.416468    -0.210825
# WorldBank_Estimate        0.034409     0.938705
# WorldBank_Year            1.000000     0.016808
# UN_Estimate               0.016808     1.000000

# %%
corr = df.corr(numeric_only=True)

plt.figure(figsize=(9,6))
sns.heatmap(corr)

plt.show()

# %%
corr = df[["IMF_Estimate", "UN_Estimate", "WorldBank_Estimate"]].corr(numeric_only=True)

plt.figure(figsize=(9,6))

sns.heatmap(corr, annot=True)

plt.show()

# %%
corr = df[["IMF_Estimate", "UN_Estimate", "WorldBank_Estimate"]].corr()

plt.figure(figsize=(9,6))

sns.heatmap(corr, annot=True, cmap = 'GnBu')

plt.show()

# %%
corr = df[["IMF_Estimate", "UN_Estimate", "WorldBank_Estimate"]].corr()

plt.figure(figsize=(9,6))

sns.heatmap(corr, annot=True, cmap = 'Purples')

plt.title("Correlation Map")


plt.show()

# %% [markdown]
# ### Bar plot

# %%
df.head()
# Out:
#   Country/Territory UN_Region  IMF_Estimate  IMF_Year  WorldBank_Estimate  \
# 1            Monaco    Europe      234316.5         0            234316.0
# 2     Liechtenstein    Europe      163507.5         0            157755.0
# 3        Luxembourg    Europe      132372.0      2023            133590.0
# 4           Ireland    Europe      114581.0      2023            100172.0
# 5           Bermuda  Americas      113371.5         0            114090.0
#
#    WorldBank_Year  UN_Estimate UN_Year
# 1            2021       234317    2021
# 2            2020       169260    2021
# 3            2021       133745    2021
# 4            2021       101109    2021
# 5            2021       112653    2021

# %%
sns.barplot(x="UN_Region", y="WorldBank_Estimate", data=df, errorbar=None)

plt.show()

# %%
sns.barplot(x="WorldBank_Estimate", y="UN_Region", data=df, errorbar=None)

plt.show()

# %%
fig = plt.figure(figsize = (8,5))

ax = sns.barplot(x = "IMF_Estimate",  y = "UN_Region",  
data = df, errorbar = None)

ax.bar_label(ax.containers[0])

plt.show()

# %%
fig = plt.figure(figsize = (8,5)) 
ax = sns.barplot(x = "UN_Region",  y = "IMF_Estimate", 
                 data = df, errorbar = None) 

ax.bar_label(ax.containers[0]) 


ax.set_title("IMF Estimate per Region")
plt.show()

# %% [markdown]
# ### Scatter Plot

# %%
df.plot(x='UN_Region', y='UN_Estimate', kind='scatter',
        figsize=(10,6),
        title="Scatter Plot")

plt.show()

# %% [markdown]
# ### Boxplot and Outliers

# %%
sns.boxplot(x=df["UN_Estimate"])

plt.show()

# %%
df["UN_Estimate"].median()
# Out:
# 6396.0

# %%
df["UN_Estimate"].min()
# Out:
# 0

# %%
q1 = df["UN_Estimate"].quantile(0.25)

# %%
q3 = df["UN_Estimate"].quantile(0.75)

# %%
df[(df["UN_Estimate"]<=df["UN_Estimate"].quantile(0.75)) & (df["UN_Estimate"]>=df["UN_Estimate"].quantile(0.25))]
# Out:
#     Country/Territory UN_Region  IMF_Estimate  IMF_Year  WorldBank_Estimate  \
# 63             Greece    Europe       22595.0      2023             20193.0
# 64               Oman      Asia       21960.0      2023             19510.0
# 66            Uruguay  Americas       21677.0      2023             17313.0
# 67           Barbados  Americas       21085.0      2023             17226.0
# 69             Guyana  Americas       20539.0      2023              9999.0
# ..                ...       ...           ...       ...                 ...
# 173        Bangladesh      Asia        2469.0      2023              2458.0
# 174   Solomon Islands   Oceania        2299.0      2023              2305.0
# 176             Kenya    Africa        2269.0      2023              2082.0
# 178             Ghana    Africa        2024.0      2023              2363.0
# 181              Laos      Asia        1858.0      2023              2536.0
#
#      WorldBank_Year  UN_Estimate UN_Year
# 63             2021        20571    2021
# 64             2021        19509    2021
# 66             2021        17313    2021
# 67             2021        17225    2021
# 69             2021         9999    2021
# ..              ...          ...     ...
# 173            2021         2450    2021
# 174            2021         2306    2021
# 176            2021         2082    2021
# 178            2021         2409    2021
# 181            2021         2569    2021
#
# [111 rows x 8 columns]

# %%
iqr = df["UN_Estimate"].quantile(0.75) - df["UN_Estimate"].quantile(0.25)

# %%
upper_boundary = q3 + 1.5*iqr
upper_boundary
# Out:
# 48791.5

# %%
lower_boundary = q1 - 1.5 * iqr
lower_boundary
# Out:
# -26012.5

# %%
df[df["UN_Estimate"]>upper_boundary]
# Out:
#          Country/Territory UN_Region  IMF_Estimate  IMF_Year  \
# 1                   Monaco    Europe      234316.5         0
# 2            Liechtenstein    Europe      163507.5         0
# 3               Luxembourg    Europe      132372.0      2023
# 4                  Ireland    Europe      114581.0      2023
# 5                  Bermuda  Americas      113371.5         0
# 6                   Norway    Europe      101103.0      2023
# 7              Switzerland    Europe       98767.0      2023
# 8                Singapore      Asia       91100.0      2023
# 10          Cayman Islands  Americas       85909.5         0
# 11                   Qatar      Asia       83891.0      2023
# 12           United States  Americas       80034.0      2023
# 13                 Iceland    Europe       75180.0      2023
# 16                 Denmark    Europe       68827.0      2023
# 17               Australia   Oceania       64964.0      2023
# 18             Netherlands    Europe       61098.0      2023
# 19               Greenland  Americas       56378.0         0
# 20                 Austria    Europe       56802.0      2023
# 21                  Israel      Asia       55535.0      2023
# 22                  Sweden    Europe       55395.0      2023
# 23                 Finland    Europe       54351.0      2023
# 24                 Belgium    Europe       53377.0      2023
# 25              San Marino    Europe       52949.0      2023
# 26                  Canada  Americas       52722.0      2023
# 27               Hong Kong      Asia       52429.0      2023
# 28                 Germany    Europe       51383.0      2023
# 31  British Virgin Islands  Americas       24722.0         0
# 32             New Zealand   Oceania       48826.0      2023
#
#     WorldBank_Estimate  WorldBank_Year  UN_Estimate UN_Year
# 1             234316.0            2021       234317    2021
# 2             157755.0            2020       169260    2021
# 3             133590.0            2021       133745    2021
# 4             100172.0            2021       101109    2021
# 5             114090.0            2021       112653    2021
# 6              89154.0            2021        89242    2021
# 7              91992.0            2021        93525    2021
# 8              72794.0            2021        66822    2021
# 10             86569.0            2021        85250    2021
# 11             66838.0            2021        66799    2021
# 12             70249.0            2021        69185    2021
# 13             68728.0            2021        69133    2021
# 16             68008.0            2021        68037    2021
# 17             60443.0            2021        66916    2021
# 18             57768.0            2021        57871    2021
# 19             54571.0            2020        58185    2021
# 20             53638.0            2021        53840    2021
# 21             52171.0            2021        54111    2021
# 22             61029.0            2021        60730    2021
# 23             53655.0            2021        53703    2021
# 24             51247.0            2021        51166    2021
# 25             45320.0            2020        50425    2021
# 26             51988.0            2021        52112    2021
# 27             49801.0            2021        49259    2021
# 28             51204.0            2021        51073    2021
# 31             37083.0               0        49444    2021
# 32             48781.0            2021        48824    2021

# %%
sns.boxplot(x=df["WorldBank_Estimate"])

plt.show()

# %%
sns.boxplot(x=df["IMF_Estimate"])

plt.show()

# %%
df[df["UN_Estimate"]>100000]
# Out:
#   Country/Territory UN_Region  IMF_Estimate  IMF_Year  WorldBank_Estimate  \
# 1            Monaco    Europe      234316.5         0            234316.0
# 2     Liechtenstein    Europe      163507.5         0            157755.0
# 3        Luxembourg    Europe      132372.0      2023            133590.0
# 4           Ireland    Europe      114581.0      2023            100172.0
# 5           Bermuda  Americas      113371.5         0            114090.0
#
#    WorldBank_Year  UN_Estimate UN_Year
# 1            2021       234317    2021
# 2            2020       169260    2021
# 3            2021       133745    2021
# 4            2021       101109    2021
# 5            2021       112653    2021

# %%
df.UN_Estimate.mean()
# Out:
# 17767.304932735427

# %%
df.shape

# %%
df.groupby("UN_Region")["UN_Estimate"].sum()
# Out:
# UN_Region
# Africa       132986
# Americas     897780
# Asia         717520
# Europe      1949318
# Oceania      252275
# World         12230
# Name: UN_Estimate, dtype: int64

# %%
df.head()
# Out:
#   Country/Territory UN_Region  IMF_Estimate  IMF_Year  WorldBank_Estimate  \
# 1            Monaco    Europe      234316.5         0            234316.0
# 2     Liechtenstein    Europe      163507.5         0            157755.0
# 3        Luxembourg    Europe      132372.0      2023            133590.0
# 4           Ireland    Europe      114581.0      2023            100172.0
# 5           Bermuda  Americas      113371.5         0            114090.0
#
#    WorldBank_Year  UN_Estimate UN_Year
# 1            2021       234317    2021
# 2            2020       169260    2021
# 3            2021       133745    2021
# 4            2021       101109    2021
# 5            2021       112653    2021

# %% [markdown]
# ## Create another dataframe called data excluding  5 countries with highest UN estimate

# %%
data = df[-(df["UN_Estimate"]>100000)]

# %%
data.head()
# Out:
#    Country/Territory UN_Region  IMF_Estimate  IMF_Year  WorldBank_Estimate  \
# 6             Norway    Europe      101103.0      2023             89154.0
# 7        Switzerland    Europe       98767.0      2023             91992.0
# 8          Singapore      Asia       91100.0      2023             72794.0
# 9        Isle of Man    Europe       43579.0         0             87158.0
# 10    Cayman Islands  Americas       85909.5         0             86569.0
#
#     WorldBank_Year  UN_Estimate UN_Year
# 6             2021        89242    2021
# 7             2021        93525    2021
# 8             2021        66822    2021
# 9             2019            0       0
# 10            2021        85250    2021

# %%
data.shape
# Out:
# (218, 8)

# %%
data.UN_Estimate.mean()
# Out:
# 14729.47247706422

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
sns.boxplot(x=data["UN_Estimate"])
plt.show()

# %%
sns.boxplot(x=df["UN_Estimate"])
plt.show()

# %% [markdown]
# ## Removing outliers

# %%
lower_q = df["UN_Estimate"].quantile(0.25)
lower_q
# Out:
# 2039.0

# %%
higher_q = df["UN_Estimate"].quantile(0.75)
higher_q
# Out:
# 20740.0

# %%
df_filtered = df[(df["UN_Estimate"] < higher_q) & (df["UN_Estimate"] > lower_q)]

# %%
df_filtered.head()
# Out:
#    Country/Territory UN_Region  IMF_Estimate  IMF_Year  WorldBank_Estimate  \
# 63            Greece    Europe       22595.0      2023             20193.0
# 64              Oman      Asia       21960.0      2023             19510.0
# 66           Uruguay  Americas       21677.0      2023             17313.0
# 67          Barbados  Americas       21085.0      2023             17226.0
# 69            Guyana  Americas       20539.0      2023              9999.0
#
#     WorldBank_Year  UN_Estimate UN_Year
# 63            2021        20571    2021
# 64            2021        19509    2021
# 66            2021        17313    2021
# 67            2021        17225    2021
# 69            2021         9999    2021

# %%
df_filtered.shape
# Out:
# (111, 8)

# %% [markdown]
# ##### There were 223 rows. now there are only around half.

# %%
df_filtered.UN_Estimate.mean()
# Out:
# 7934.8378378378375

# %%
df_filtered.WorldBank_Estimate.mean()
# Out:
# 7924.867117117117

# %%
df_filtered.UN_Estimate.mean()
# Out:
# 7934.8378378378375

# %%
df_filtered.IMF_Estimate.mean()
# Out:
# 8939.22972972973
